# %%
'''
What is seaborn in python?
Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative
statistical graphics. Seaborn is built on top of matplotlib and integrates closely with pandas data structures. It helps you explore and
understand your data.
Seaborn provides a variety of plot types, including:
Relational plots: These plots show the relationship between two variables. Examples include scatter plots, line plots, and bar charts.
Categorical plots: These plots show the distribution of a categorical variable. Examples include histograms and box plots.
Distribution plots: These plots show the distribution of a continuous variable. Examples include histograms and kernel density
estimates.
Regression plots: These plots show the relationship between a dependent variable and one or more independent variables.
Examples include linear regression plots and logistic regression plots.
Matrix plots: These plots show the relationship between multiple variables. Examples include heatmaps and correlation matrices.
Seaborn also provides a number of functions for customizing the appearance of your plots. For example, you can change the colors,
fonts, and sizes of the elements in your plot.
'''
# Out:
# '\nWhat is seaborn in python?\nSeaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative\nstatistical graphics. Seaborn is built on top of matplotlib and integrates closely with pandas data structures. It helps you explore and\nunderstand your data.\nSeaborn provides a variety of plot types, including:\nRelational plots: These plots show the relationship between two variables. Examples include scatter plots, line plots, and bar charts.\nCategorical plots: These plots show the distribution of a categorical variable. Examples include histograms and box plots.\nDistribution plots: These plots show the distribution of a continuous variable. Examples include histograms and kernel density\nestimates.\nRegression plots: These plots show the relationship between a dependent variable and one or more independent variables.\nExamples include linear regression plots and logistic regression plots.\nMatrix plots: T
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.describe
# Out:
# <bound method NDFrame.describe of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
# scatter -> axis level function
sns.color_palette("pastel")
sns.scatterplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)

# %%
'''
This plot shows the relationship between five variables in the tips dataset using a
single call to the seaborn function relplot(). Notice how we provided only the names of the
variables and their roles in the plot. Unlike when using matplotlib directly, it wasn’t necessary to specify
attributes of the plot elements in terms of the color values or marker codes. Behind the scenes, seaborn handled the
translation from values in the dataframe to arguments that matplotlib understands. This declarative approach lets you
stay focused on the questions that you want to answer, rather than on the details of how to control matplotlib.
'''
# Out:
# '\nThis plot shows the relationship between five variables in the tips dataset using a \nsingle call to the seaborn function relplot(). Notice how we provided only the names of the \nvariables and their roles in the plot. Unlike when using matplotlib directly, it wasn’t necessary to specify \nattributes of the plot elements in terms of the color values or marker codes. Behind the scenes, seaborn handled the \ntranslation from values in the dataframe to arguments that matplotlib understands. This declarative approach lets you\nstay focused on the questions that you want to answer, rather than on the details of how to control matplotlib.\n'

# %%
#Statistical analyses require knowledge about the distribution of variables in your dataset.
#The seaborn function displot() supports several approaches to visualizing distributions.
#These include classic techniques like histograms and computationally-intensive approaches like kernel density estimation:

sns.displot(data=tips, x="total_bill", col="time", kde=True)

# %%
#Plots for categorical data
#Several specialized plot types in seaborn are oriented towards visualizing categorical data.
#They can be accessed through catplot(). These plots offer different levels of granularity.
#At the finest level, you may wish to see every observation by drawing a “swarm” plot: a scatter plot that adjusts
#the positions of the points along the categorical axis so that they don’t overlap:

sns.catplot(data=tips, kind="swarm", x="day", y="total_bill", hue="smoker")

# %%
#Violinplots
#A different approach is a violinplot(), which combines a boxplot with the kernel density estimation procedure
#you could use kernel density estimation to represent the underlying distribution that the points are sampled from:

sns.catplot(data=tips, kind="violin", x="day", y="total_bill", hue="smoker", split=True)

# %%
#This approach uses the kernel density estimate to provide a richer description of the distribution of values.
#Additionally, the quartile and whisker values from the boxplot are shown inside the violin.
#The downside is that, because the violinplot uses a KDE, there are some other parameters that may need tweaking,
#adding some complexity relative to the straightforward boxplot:

sns.catplot(
    data=tips, x="total_bill", y="day", hue="sex",
    kind="violin", bw_adjust=.5, cut=0,
)

# %%
 #you could show only the mean value and its confidence interval within each nested category:

sns.catplot(data=tips, kind="bar", x="day", y="total_bill", hue="smoker")

# %%
# scatter -> figure level finction
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter')

# %%
plt.figure(figsize=(10, 6))
sns.set_theme(style='darkgrid', palette='Set2', font_scale=1.2)
sns.scatterplot(x='total_bill', y='tip', data=tips,
hue='sex', style='time', size='size')
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=tips,
kind='scatter', hue='sex', style='time')

# %%
#Line plot
df = px.data.gapminder()

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
df1 = df[df['country'] == 'India']
df1
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# ...

# %%
# axis level func
plt.figure(figsize=(10, 6))
sns.lineplot(x='year', y='lifeExp', data=df1)
plt.show()

# %%
# figure level
sns.relplot(x='year', y='lifeExp', data=df1, kind='line')

# %%
df2 = df[df['country'].isin(['India', 'Pakistan', 'China'])]
df2.head()
# Out:
#     country continent  year   lifeExp        pop   gdpPercap iso_alpha  \
# 288   China      Asia  1952  44.00000  556263527  400.448611       CHN
# 289   China      Asia  1957  50.54896  637408000  575.987001       CHN
# 290   China      Asia  1962  44.50136  665770000  487.674018       CHN
# 291   China      Asia  1967  58.38112  754550000  612.705693       CHN
# 292   China      Asia  1972  63.11888  862030000  676.900092       CHN
#
#      iso_num
# 288      156
# 289      156
# 290      156
# 291      156
# 292      156

# %%
sns.relplot(x='year', y='lifeExp', data=df2, hue='country', kind='line')

# %%
sns.lineplot(x='year', y='lifeExp', data=df2, hue='country')
# Out:
# <AxesSubplot:xlabel='year', ylabel='lifeExp'>

# %%
df3 = df[df['country'].isin(['India', 'Brazil', 'Germany'])]
df3
# Out:
#      country continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# 168   Brazil  Americas  1952   50.917    56602560   2108.944355       BRA
# 169   Brazil  Americas  1957   53.285    65551171   2487.365989       BRA
# 170   Brazil  Americas  1962   55.665    76039390   3336.585802       BRA
# 171   Brazil  Americas  1967   57.632    88049823   3429.864357       BRA
# 172   Brazil  Americas  1972   59.504   100840058   4985.711467       BRA
# 173   Brazil  Americas  1977   61.489   114313951   6660.118654       BRA
# 174   Brazil  Americas  1982   63.336   128962939   7030.835878       BRA
# 175   Brazil  Americas  1987   65.205   142938076   7807.095818       BRA
# 176   Brazil  Americas  1992   67.057   155975974   6950.283021       BRA
# 177   Brazil  Americas  1997   69.388   168546719   7957.980824       BRA
# 178   Brazil  Americas  2002   71.006   179914212   8131.212843       BRA
# 179   Brazil  Americas  2007   72.390   190010647   9065.800825       BRA
# ...

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='year', y='lifeExp', data=df3, hue='country', style='continent')
# Out:
# <AxesSubplot:xlabel='year', ylabel='lifeExp'>

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter', col='sex')

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter', row='sex')

# %%
'''
Distribution Plots**

used for univariate analysis
used to find out the distribution
Range of the observation
Central Tendency
is the data bimodal?
Are there outliers?

Plots under distribution plot
histplot
kdeplot
rugplot
'''
# Out:
# '\nDistribution Plots**\n\nused for univariate analysis\nused to find out the distribution\nRange of the observation\nCentral Tendency\nis the data bimodal?\nAre there outliers?\n\nPlots under distribution plot\nhistplot\nkdeplot\nrugplot\n'

# %%
# hist
sns.histplot(data=tips, x='total_bill')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(data=tips, x='total_bill', kind='hist')

# %%
sns.displot(data=tips, x='total_bill', bins=20)

# %%
sns.displot(data=tips, x='day', kind='hist')

# %%
sns.displot(data=tips, x='tip', kind='hist', hue='sex')

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.kdeplot(data=tips, x='total_bill')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data=tips, x='total_bill', hue='sex')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
# bivariate histogram
sns.histplot(data=tips, x='total_bill', y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.displot(data=tips, x='total_bill', y='tip', kind='hist', height=8)

# %%
sns.kdeplot(data=tips, x='total_bill', y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
df4 = df.pivot(index='country', columns='year', values='lifeExp')
df4
# Out:
# year                  1952    1957    1962    1967    1972    1977    1982  \
# country
# Afghanistan         28.801  30.332  31.997  34.020  36.088  38.438  39.854
# Albania             55.230  59.280  64.820  66.220  67.690  68.930  70.420
# Algeria             43.077  45.685  48.303  51.407  54.518  58.014  61.368
# Angola              30.015  31.999  34.000  35.985  37.928  39.483  39.942
# Argentina           62.485  64.399  65.142  65.634  67.065  68.481  69.942
# ...                    ...     ...     ...     ...     ...     ...     ...
# Vietnam             40.412  42.887  45.363  47.838  50.254  55.764  58.816
# West Bank and Gaza  43.160  45.671  48.127  51.631  56.532  60.765  64.406
# Yemen, Rep.         32.548  33.970  35.180  36.984  39.848  44.175  49.113
# Zambia              42.038  44.077  46.023  47.768  50.107  51.386  51.821
# Zimbabwe            48.451  50.469  52.358  53.995  55.635  57.674  60.363
#
# year                  1987    1992    1997    2002    2007
# ...

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(df4)
# Out:
# <AxesSubplot:xlabel='year', ylabel='country'>

# %%
df5 = df[df['continent'] == 'Europe']
df5.head()
# Out:
#     country continent  year  lifeExp      pop    gdpPercap iso_alpha  iso_num
# 12  Albania    Europe  1952    55.23  1282697  1601.056136       ALB        8
# 13  Albania    Europe  1957    59.28  1476505  1942.284244       ALB        8
# 14  Albania    Europe  1962    64.82  1728137  2312.888958       ALB        8
# 15  Albania    Europe  1967    66.22  1984060  2760.196931       ALB        8
# 16  Albania    Europe  1972    67.69  2263554  3313.422188       ALB        8

# %%
df6 = df5.pivot(index='country', columns='year', values='lifeExp')
df6
# Out:
# year                      1952    1957    1962    1967    1972    1977  \
# country
# Albania                 55.230  59.280  64.820  66.220  67.690  68.930
# Austria                 66.800  67.480  69.540  70.140  70.630  72.170
# Belgium                 68.000  69.240  70.250  70.940  71.440  72.800
# Bosnia and Herzegovina  53.820  58.450  61.930  64.790  67.450  69.860
# Bulgaria                59.600  66.610  69.510  70.420  70.900  70.810
# Croatia                 61.210  64.770  67.130  68.500  69.610  70.640
# Czech Republic          66.870  69.030  69.900  70.380  70.290  70.710
# Denmark                 70.780  71.810  72.350  72.960  73.470  74.690
# Finland                 66.550  67.490  68.750  69.830  70.870  72.520
# France                  67.410  68.930  70.510  71.550  72.380  73.830
# Germany                 67.500  69.100  70.300  70.800  71.000  72.500
# Greece                  65.860  67.860  69.510  71.000  72.340  73.680
# ...

# %%
plt.figure(figsize=(10, 10))
sns.set_theme(style='darkgrid', palette='Set2', font_scale=1.2)
sns.heatmap(df6, annot=True, linewidths=0.1, cmap='viridis')
# Out:
# <AxesSubplot:xlabel='year', ylabel='country'>

# %%
'''
Boxplots
The first is the familiar boxplot(). This kind of plot shows the three quartile values of the distribution
along with extreme values. The “whiskers” extend to points that lie within 1.5 IQRs of the lower and upper quartile,
and then observations that fall outside this range are displayed independently.
This means that each value in the boxplot corresponds to an actual observation in the data.
'''
sns.catplot(data=tips, x="day", y="total_bill", kind="box")

# %%
#When adding a hue semantic, the box for each level of the semantic variable is made narrower and shifted along the
#categorical axis:

sns.catplot(data=tips, x="day", y="total_bill", hue="smoker", kind="box")

#This behavior is called “dodging”, and it is controlled by the dodge parameter. By default (as of v0.13.0),
#elements dodge only if they would otherwise overlap:
