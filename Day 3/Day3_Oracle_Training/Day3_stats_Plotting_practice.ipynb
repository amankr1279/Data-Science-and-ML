# %%
##Handling missing data
##pandas uses different sentinel values to represent a missing (also referred to as NA) depending on the data type.

import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(
    {
        "A": [1, 2.1, np.nan, 4.7, 5.6, 6.8],
        "B": [0.25, np.nan, np.nan, 4, 12.2, 14.4],
    }
)

# %%
df
# Out:
#      A      B
# 0  1.0   0.25
# 1  2.1    NaN
# 2  NaN    NaN
# 3  4.7   4.00
# 4  5.6  12.20
# 5  6.8  14.40

# %%
df.fillna(0)
# Out:
#      A      B
# 0  1.0   0.25
# 1  2.1   0.00
# 2  0.0   0.00
# 3  4.7   4.00
# 4  5.6  12.20
# 5  6.8  14.40

# %%
dff = pd.DataFrame(np.arange(30, dtype=np.float64).reshape(10, 3), columns=list("ABC"))

# %%
dff
# Out:
#       A     B     C
# 0   0.0   1.0   2.0
# 1   3.0   4.0   5.0
# 2   6.0   7.0   8.0
# 3   9.0  10.0  11.0
# 4  12.0  13.0  14.0
# 5  15.0  16.0  17.0
# 6  18.0  19.0  20.0
# 7  21.0  22.0  23.0
# 8  24.0  25.0  26.0
# 9  27.0  28.0  29.0

# %%
dff.iloc[3:5, 0] = np.nan

# %%
dff
# Out:
#       A     B     C
# 0   0.0   1.0   2.0
# 1   3.0   4.0   5.0
# 2   6.0   7.0   8.0
# 3   NaN  10.0  11.0
# 4   NaN  13.0  14.0
# 5  15.0  16.0  17.0
# 6  18.0  19.0  20.0
# 7  21.0  22.0  23.0
# 8  24.0  25.0  26.0
# 9  27.0  28.0  29.0

# %%
dff.iloc[4:6, 1] = np.nan

# %%
dff
# Out:
#       A     B     C
# 0   0.0   1.0   2.0
# 1   3.0   4.0   5.0
# 2   6.0   7.0   8.0
# 3   NaN  10.0  11.0
# 4   NaN   NaN  14.0
# 5  15.0   NaN  17.0
# 6  18.0  19.0  20.0
# 7  21.0  22.0  23.0
# 8  24.0  25.0  26.0
# 9  27.0  28.0  29.0

# %%
dff.iloc[5:8, 2] = np.nan

# %%
dff
# Out:
#       A     B     C
# 0   0.0   1.0   2.0
# 1   3.0   4.0   5.0
# 2   6.0   7.0   8.0
# 3   NaN  10.0  11.0
# 4   NaN   NaN  14.0
# 5  15.0   NaN   NaN
# 6  18.0  19.0   NaN
# 7  21.0  22.0   NaN
# 8  24.0  25.0  26.0
# 9  27.0  28.0  29.0

# %%
dff.fillna(dff.mean())

##dff.where(pd.notna(dff), dff.mean(), axis="columns")
# Out:
#        A     B          C
# 0   0.00   1.0   2.000000
# 1   3.00   4.0   5.000000
# 2   6.00   7.0   8.000000
# 3  14.25  10.0  11.000000
# 4  14.25  14.5  14.000000
# 5  15.00  14.5  13.571429
# 6  18.00  19.0  13.571429
# 7  21.00  22.0  13.571429
# 8  24.00  25.0  26.000000
# 9  27.00  28.0  29.000000

# %%
df = pd.DataFrame(
    {
        "A": [1, 2.1, np.nan, 4.7, 5.6, 6.8],
        "B": [0.25, np.nan, np.nan, 4, 12.2, 14.4],
    }
)

# %%
df
# Out:
#      A      B
# 0  1.0   0.25
# 1  2.1    NaN
# 2  NaN    NaN
# 3  4.7   4.00
# 4  5.6  12.20
# 5  6.8  14.40

# %%
df.interpolate()
# Out:
#      A      B
# 0  1.0   0.25
# 1  2.1   1.50
# 2  3.4   2.75
# 3  4.7   4.00
# 4  5.6  12.20
# 5  6.8  14.40

# %%
help(df.interpolate)
# Out:
# Help on method interpolate in module pandas.core.frame:
#
# interpolate(method: 'str' = 'linear', axis: 'Axis' = 0, limit: 'int | None' = None, inplace: 'bool' = False, limit_direction: 'str | None' = None, limit_area: 'str | None' = None, downcast: 'str | None' = None, **kwargs) -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Fill NaN values using an interpolation method.
#
#     Please note that only ``method='linear'`` is supported for
#     DataFrame/Series with a MultiIndex.
#
#     Parameters
#     ----------
#     method : str, default 'linear'
#         Interpolation technique to use. One of:
#
#         * 'linear': Ignore the index and treat the values as equally
#           spaced. This is the only method supported on MultiIndexes.
#         * 'time': Works on daily and higher resolution data to interpolate
#           given length of interval.
#         * 'index', 'values': use the actual numerical values of the index.
# ...

# %%
##Missing data and opertions with fill values
df = pd.DataFrame({'one': pd.Series([1,2,3],index=['a','b','c']),'two':pd.Series([4,5,6,7],index=['a','b','c','d']),
                   'three':pd.Series([8,9,10],index=['b','c','d'])})

# %%
df
# Out:
#    one  two  three
# a  1.0    4    NaN
# b  2.0    5    8.0
# c  3.0    6    9.0
# d  NaN    7   10.0

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df_missing = df.replace(np.nan,0)

# %%
df_missing
# Out:
#    one  two  three
# a  1.0    4    0.0
# b  2.0    5    8.0
# c  3.0    6    9.0
# d  0.0    7   10.0

# %%
df_missing.plot()
# Out:
# <AxesSubplot:>

# %%
df2 = pd.DataFrame({'one': pd.Series([1,2,3],index=['a','c','d']),'two':pd.Series([4,6,7],index=['a','b','c']),
                   'three':pd.Series([8,9,10],index=['a','b','d'])})

# %%
df2
# Out:
#    one  two  three
# a  1.0  4.0    8.0
# b  NaN  6.0    9.0
# c  2.0  7.0    NaN
# d  3.0  NaN   10.0

# %%
#Adding data frames with missing values
print(df.add(df2))
# Out:
#    one   two  three
# a  2.0   8.0    NaN
# b  NaN  11.0   17.0
# c  5.0  13.0    NaN
# d  NaN   NaN   20.0

# %%
df2_missing = df2.replace(np.nan,0)

# %%
df2_missing
# Out:
#    one  two  three
# a  1.0  4.0    8.0
# b  0.0  6.0    9.0
# c  2.0  7.0    0.0
# d  3.0  0.0   10.0

# %%
#Adding data frmaes with filled values
print(df.add(df2,fill_value=0))
# Out:
#    one   two  three
# a  2.0   8.0    8.0
# b  2.0  11.0   17.0
# c  5.0  13.0    9.0
# d  3.0   7.0   20.0

# %%
df2.plot()
# Out:
# <AxesSubplot:>

# %%
df2_missing.plot()
# Out:
# <AxesSubplot:>

# %%
df =pd.DataFrame(np.random.randn(5,3),index=['a','b','e','f','h'],columns=['one','two','three'])

# %%
df
# Out:
#         one       two     three
# a -0.681401 -0.559266  0.061146
# b -0.005842 -0.212984 -0.514963
# e  0.717501 -0.285720  1.057713
# f -0.818296 -2.204871  0.405237
# h  1.036532 -0.101737  0.288203

# %%
df = df.reindex(['a','b','c','d','e','f','g','h'])

# %%
df
# Out:
#         one       two     three
# a -0.681401 -0.559266  0.061146
# b -0.005842 -0.212984 -0.514963
# c       NaN       NaN       NaN
# d       NaN       NaN       NaN
# e  0.717501 -0.285720  1.057713
# f -0.818296 -2.204871  0.405237
# g       NaN       NaN       NaN
# h  1.036532 -0.101737  0.288203

# %%
##Droping missing values
print(df.dropna())
# Out:
#         one       two     three
# a -0.681401 -0.559266  0.061146
# b -0.005842 -0.212984 -0.514963
# e  0.717501 -0.285720  1.057713
# f -0.818296 -2.204871  0.405237
# h  1.036532 -0.101737  0.288203

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df=pd.DataFrame({'A':[10,20,30,40,50,700],'B':[8000,90,100,75,58,63]})

# %%
df
# Out:
#      A     B
# 0   10  8000
# 1   20    90
# 2   30   100
# 3   40    75
# 4   50    58
# 5  700    63

# %%
##Replacing generic values
print(df.replace({700:70,8000:80}))
# Out:
#     A    B
# 0  10   80
# 1  20   90
# 2  30  100
# 3  40   75
# 4  50   58
# 5  70   63

# %%
##Descriptive statistics
df=pd.DataFrame({'A':[1,2,3,5,np.NaN],'B':[7,8,np.NaN,10,1],'c':[np.NaN,4,3,2,0]})

# %%
df
# Out:
#      A     B    c
# 0  1.0   7.0  NaN
# 1  2.0   8.0  4.0
# 2  3.0   NaN  3.0
# 3  5.0  10.0  2.0
# 4  NaN   1.0  0.0

# %%
##print columnwise mean
print(df.mean(0))
# Out:
# A    2.75
# B    6.50
# c    2.25
# dtype: float64

# %%
#Print rowwiswe mean
print(df.mean(1))
# Out:
# 0    4.000000
# 1    4.666667
# 2    3.000000
# 3    5.666667
# 4    0.500000
# dtype: float64

# %%
print(df.mean(0,skipna=False))
# Out:
# A   NaN
# B   NaN
# c   NaN
# dtype: float64

# %%
print(df.mean(1,skipna=False))
# Out:
# 0         NaN
# 1    4.666667
# 2         NaN
# 3    5.666667
# 4         NaN
# dtype: float64

# %%
##value_counts series method and top-level function compute a histogram of a 1D array of vales
df=pd.DataFrame ({"A":np.random.randint(0,7,size=10),
                  "B":np.random.randint(-10,15,size=10)})
print ("DATA FRAME")

data=np.random.randint(0,7,size=20)
s=pd.Series(data)
print(s)
print(s.value_counts())
s.plot()

#mode function is used to get the most friequently occuring values
print("MODE:")
modedf = df.mode()
# Out:
# DATA FRAME
# 0     2
# 1     4
# 2     4
# 3     3
# 4     3
# 5     4
# 6     5
# 7     1
# 8     1
# 9     2
# 10    1
# 11    3
# 12    4
# 13    3
# 14    5
# 15    1
# 16    5
# 17    2
# 18    5
# 19    6
# dtype: int32
# 4    4
# 3    4
# 5    4
# 1    4
# 2    3
# 6    1
# dtype: int64
# MODE:

# %%
df
# Out:
#    A   B
# 0  0   7
# 1  3   7
# 2  0 -10
# 3  2  14
# 4  2   2
# 5  0  14
# 6  2   5
# 7  3 -10
# 8  3   8
# 9  1   3

# %%
print(modedf)
# Out:
#    A   B
# 0  2 -10

# %%
s=pd.Series([1,2,3,5,4])

# %%
##Percent_change compares every element with its prior element and computes the change percentage
print(s.pct_change())

##by default pct_change operates on columns to apply the function on rows use axis=1( argument)
# Out:
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.666667
# 4   -0.200000
# dtype: float64

# %%
##covariance #Covariance is applies on series data to compute covariance between series objects

#the cov method automatically excludes NA
#Covariance
